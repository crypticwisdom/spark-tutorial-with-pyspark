# %% [markdown]
# ## Topics:
# - Dataframe
# - Reading the data from CSV
# - Checking the datatypes of the columns in the Dataframe and also Infer schema with the inferSchema' argument in ...read.csv(...) / .option(...).csv(...) method.
# - Select columns and indexing
# - Check describe option similar to pandas
# - Adding new columns
# - Dropping columns
# - Renaming columns

# %%
from pyspark.sql import SparkSession


spark = SparkSession.builder.appName('SparkOperation').getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://host.docker.internal:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>SparkOperation</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.csv('./data/testdata.csv', header=True, inferSchema=True)

# Schema inference, which means that we want Spark to take a best guess at what
# the schema of our DataFrame should be.

# %%
# Print Schema of the dataframe
df.printSchema() # Gives a tree structure of the dataframe
# Out:
# root
#  |-- MSISDN: integer (nullable = true)
#  |-- NID: string (nullable = true)
#  |-- NID_LEN: integer (nullable = true)
#  |-- CUSTOMERIDNAME: string (nullable = true)
#  |-- EMAIL: string (nullable = true)
#  |-- GROSS_DATE: string (nullable = true)
#  |-- CUSTOMER_TYPE: string (nullable = true)
#  |-- USERTYPE: string (nullable = true)
#  |-- SUBSCRIBERCAT: string (nullable = true)
#  |-- SUBSCRIBERSUBCAT: string (nullable = true)
#  |-- SEGMENT: string (nullable = true)
#  |-- POSTPAID_TARIFF: string (nullable = true)
#  |-- POSTPAID_MAINPRODUCT: string (nullable = true)
#  |-- POSTPAID_SUBPRODUCT: string (nullable = true)
#  |-- NATIONALITY: string (nullable = true)
#  |-- AON_DAYS: integer (nullable = true)
#  |-- AON_MONTH: double (nullable = true)
#  |-- AON_YEAR: double (nullable = true)
#  |-- ALTERNATE_MOB_NUM: string (nullable = true)
#  |-- FAVOURITE_LOCATION: string (nullable = true)
#  |-- DAYS_INACT  BAL_1: integer (nullable = true)
#  |-- BAL_2: double (nullable = true)
#  |-- BAL_3: double (nullable = true)
#  |-- DATA_USERS: double (nullable = true)
#  |-- PACK_USERS: string (nullable = true)
#  |-- PACK_90D: string (nullable = true)
#  |-- PACK_30D: integer (nullable = true)
#  |-- DAILY_PACK_90D: integer (nullable = true)
#  |-- DAILY_PACK_30D: integer (nullable = true)
#  |-- WEEKLY_PACK_90D: integer (nullable = true)
#  |-- WEEKLY_PACK_30D: integer (nullable = true)
#  |-- MONTHLY_PACK_90D: integer (nullable = true)
#  |-- MONTHLY_PACK_30D: integer (nullable = true)
#  |-- RECHARGE_VAL_30D: integer (nullable = true)
#  |-- RECHARGE_VAL_D1: double (nullable = true)
#  |-- RECHARGE_VAL_D2: double (nullable = true)
#  |-- RECHARGE_VAL_D3: double (nullable = true)
#  |-- AIRTIME_USG YOUTH_PACK: double (nullable = true)
#  |-- TOTAL_ARPU: double (nullable = true)
#  |-- ONNET_REVENUE: string (nullable = true)
#  |-- XNET_REVENUE: double (nullable = true)
#  |-- ONNET_TOTAL_MINS_90D: double (nullable = true)
#  |-- ONNET_TOTAL_MINS_30D: double (nullable = true)
#  |-- XNET_TOTAL_MINS_90D: double (nullable = true)
#  |-- XNET_TOTAL_MINS_30D: double (nullable = true)
#  |-- VOICE_INCOMING_ARPU SMS_ARPU: double (nullable = true)
#  |-- DATA_USG_GB_90D: double (nullable = true)
#  |-- DATA_USG_GB_30D: double (nullable = true)
#  |-- DATA_PAYG_USG_GB_90D: double (nullable = true)
#  |-- DATA_PAYG_USG_GB_30D: double (nullable = true)
#  |-- TOTAL_DATA_ARPU_90D: double (nullable = true)
#  |-- TOTAL_DATA_ARPU_30D: double (nullable = true)
#  |-- TOTAL_DATA_PAYG_ARPU_90D: double (nullable = true)
#  |-- TOTAL_DATA_PAYG_ARPU_30D: double (nullable = true)
#  |-- ILD_ARPU: double (nullable = true)
#  |-- ILD_SMS_ARPU: double (nullable = true)
#  |-- DEVICE_SUBTYPE_1: double (nullable = true)
#  |-- DEVICE_SUBTYPE_2: double (nullable = true)
#  |-- DEVICE_SUBTYPE_3: double (nullable = true)
#  |-- OS_SYSTEM_1: string (nullable = true)
#  |-- OS_SYSTEM_2: string (nullable = true)
#  |-- OS_SYSTEM_3: string (nullable = true)
#  |-- TECHNOLOGY_1: string (nullable = true)
#  |-- TECHNOLOGY_2: string (nullable = true)
#  |-- TECHNOLOGY_3: string (nullable = true)
#  |-- SIM_TYPE_1: string (nullable = true)
#  |-- SIM_TYPE_2: string (nullable = true)
#  |-- SIM_TYPE_3: string (nullable = true)
#  |-- DUAL_SIM_1: string (nullable = true)
#  |-- DUAL_SIM_2: string (nullable = true)
#  |-- DUAL_SIM_3: string (nullable = true)
#  |-- ESIM_1: string (nullable = true)
#  |-- ESIM_2: string (nullable = true)
#  |-- ESIM_3: string (nullable = true)

# %%
# list all columns in the dataframe, outputs a python list with string values.
df.columns
# Out:
# ['MSISDN',
#  'NID',
#  'NID_LEN',
#  'CUSTOMERIDNAME',
#  'EMAIL',
#  'GROSS_DATE',
#  'CUSTOMER_TYPE',
#  'USERTYPE',
#  'SUBSCRIBERCAT',
#  'SUBSCRIBERSUBCAT',
#  'SEGMENT',
#  'POSTPAID_TARIFF',
#  'POSTPAID_MAINPRODUCT',
#  'POSTPAID_SUBPRODUCT',
#  'NATIONALITY',
#  'AON_DAYS',
#  'AON_MONTH',
#  'AON_YEAR',
#  'ALTERNATE_MOB_NUM',
#  'FAVOURITE_LOCATION',
#  'DAYS_INACT  BAL_1',
#  'BAL_2',
#  'BAL_3',
#  'DATA_USERS',
#  'PACK_USERS',
#  'PACK_90D',
#  'PACK_30D',
#  'DAILY_PACK_90D',
#  'DAILY_PACK_30D',
#  'WEEKLY_PACK_90D',
#  'WEEKLY_PACK_30D',
#  'MONTHLY_PACK_90D',
#  'MONTHLY_PACK_30D',
#  'RECHARGE_VAL_30D',
#  'RECHARGE_VAL_D1',
#  'RECHARGE_VAL_D2',
#  'RECHARGE_VAL_D3',
#  'AIRTIME_USG YOUTH_PACK',
#  'TOTAL_ARPU',
#  'ONNET_REVENUE',
#  'XNET_REVENUE',
#  'ONNET_TOTAL_MINS_90D',
#  'ONNET_TOTAL_MINS_30D',
#  'XNET_TOTAL_MINS_90D',
#  'XNET_TOTAL_MINS_30D',
#  'VOICE_INCOMING_ARPU SMS_ARPU',
#  'DATA_USG_GB_90D',
#  'DATA_USG_GB_30D',
#  'DATA_PAYG_USG_GB_90D',
#  'DATA_PAYG_USG_GB_30D',
#  'TOTAL_DATA_ARPU_90D',
#  'TOTAL_DATA_ARPU_30D',
#  'TOTAL_DATA_PAYG_ARPU_90D',
#  'TOTAL_DATA_PAYG_ARPU_30D',
#  'ILD_ARPU',
#  'ILD_SMS_ARPU',
#  'DEVICE_SUBTYPE_1',
#  'DEVICE_SUBTYPE_2',
#  'DEVICE_SUBTYPE_3',
#  'OS_SYSTEM_1',
#  'OS_SYSTEM_2',
#  'OS_SYSTEM_3',
#  'TECHNOLOGY_1',
#  'TECHNOLOGY_2',
#  'TECHNOLOGY_3',
#  'SIM_TYPE_1',
#  'SIM_TYPE_2',
#  'SIM_TYPE_3',
#  'DUAL_SIM_1',
#  'DUAL_SIM_2',
#  'DUAL_SIM_3',
#  'ESIM_1',
#  'ESIM_2',
#  'ESIM_3']

# %%
# Show dataframe and rows
df.show(2)  # Show the first 5 rows

# df.head(5)  # Get the first 5 rows as a list of Row objects

# df.count()  # Count the number of rows in the DataFrame

# df.tail(5)  # Get the last 5 rows as a list of Row objects

# df.describe().show()  # Get summary statistics for numeric columns
# Out:
# +--------+--------------+-------+--------------------+--------------------+----------+-------------+--------+-------------+----------------+-------+---------------+--------------------+-------------------+-----------+--------+---------+--------+-----------------+------------------+-----------------+------+------+----------+----------+--------+--------+--------------+--------------+---------------+---------------+----------------+----------------+----------------+---------------+---------------+---------------+----------------------+----------+-------------+------------+--------------------+--------------------+-------------------+-------------------+----------------------------+---------------+---------------+--------------------+--------------------+-------------------+-------------------+------------------------+------------------------+--------+------------+----------------+----------------+----------------+-----------+-----------+-----------+------------+------------+------------+----------+----------+----------+----------+----------+----------+--------+--------+--------+
# |  MSISDN|           NID|NID_LEN|      CUSTOMERIDNAME|               EMAIL|GROSS_DATE|CUSTOMER_TYPE|USERTYPE|SUBSCRIBERCAT|SUBSCRIBERSUBCAT|SEGMENT|POSTPAID_TARIFF|POSTPAID_MAINPRODUCT|POSTPAID_SUBPRODUCT|NATIONALITY|AON_DAYS|AON_MONTH|AON_YEAR|ALTERNATE_MOB_NUM|FAVOURITE_LOCATION|DAYS_INACT  BAL_1| BAL_2| BAL_3|DATA_USERS|PACK_USERS|PACK_90D|PACK_30D|DAILY_PACK_90D|DAILY_PACK_30D|WEEKLY_PACK_90D|WEEKLY_PACK_30D|MONTHLY_PACK_90D|MONTHLY_PACK_30D|RECHARGE_VAL_30D|RECHARGE_VAL_D1|RECHARGE_VAL_D2|RECHARGE_VAL_D3|AIRTIME_USG YOUTH_PACK|TOTAL_ARPU|ONNET_REVENUE|XNET_REVENUE|ONNET_TOTAL_MINS_90D|ONNET_TOTAL_MINS_30D|XNET_TOTAL_MINS_90D|XNET_TOTAL_MINS_30D|VOICE_INCOMING_ARPU SMS_ARPU|DATA_USG_GB_90D|DATA_USG_GB_30D|DATA_PAYG_USG_GB_90D|DATA_PAYG_USG_GB_30D|TOTAL_DATA_ARPU_90D|TOTAL_DATA_ARPU_30D|TOTAL_DATA_PAYG_ARPU_90D|TOTAL_DATA_PAYG_ARPU_30D|ILD_ARPU|ILD_SMS_ARPU|DEVICE_SUBTYPE_1|DEVICE_SUBTYPE_2|DEVICE_SUBTYPE_3|OS_SYSTEM_1|OS_SYSTEM_2|OS_SYSTEM_3|TECHNOLOGY_1|TECHNOLOGY_2|TECHNOLOGY_3|SIM_TYPE_1|SIM_TYPE_2|SIM_TYPE_3|DUAL_SIM_1|DUAL_SIM_2|DUAL_SIM_3|  ESIM_1|  ESIM_2|  ESIM_3|
# +--------+--------------+-------+--------------------+--------------------+----------+-------------+--------+-------------+----------------+-------+---------------+--------------------+-------------------+-----------+--------+---------+--------+-----------------+------------------+-----------------+------+------+----------+----------+--------+--------+--------------+--------------+---------------+---------------+----------------+----------------+----------------+---------------+---------------+---------------+----------------------+----------+-------------+------------+--------------------+--------------------+-------------------+-------------------+----------------------------+---------------+---------------+--------------------+--------------------+-------------------+-------------------+------------------------+------------------------+--------+------------+----------------+----------------+----------------+-----------+-----------+-----------+------------+------------+------------+----------+----------+----------+----------+----------+----------+--------+--------+--------+
# |54924133|J0711874907942|     14|        WENSLEY JEAN|JEANPOMPIER0517@G...| 21-Jul-15|       MOBILE| PREPAID|   INDIVIDUAL|            GOLD|  IVORY|           NULL|                NULL|               NULL|       HOME|    3222|   105.84|    8.83|             NULL|        BELLE ROSE|                0|1.8619|1.8621|    1.8621|         Y|       Y|       3|             2|             3|              2|           NULL|            NULL|            NULL|            NULL|            0.0|            0.0|            0.0|                   0.0|     78.67|            N|       80.99|               17.56|                4.69|              14.63|                2.8|                        1.32|           NULL|           2.32|                 0.0|                0.99|               0.99|               0.01|                     0.0|                   18.26|    NULL|        1.64|             0.3|            NULL|            NULL| Smartphone| Smartphone| Smartphone|     Android|     Android|     Android|        5G|        5G|        5G|    USIM  |    USIM  |    USIM  |DUAL SIM|DUAL SIM|DUAL SIM|
# |54846497|B160985220041C|     14|MARIE ANGELO BOOD...|                NULL| 10-Apr-24|       MOBILE| PREPAID|   INDIVIDUAL|            GOLD| SILVER|           NULL|                NULL|               NULL|       HOME|     417|    13.68|    1.14|             NULL|         ST HUBERT|                0|8.7E-4|   0.0|       0.0|         Y|       Y|      19|            11|            19|             11|           NULL|            NULL|               1|            NULL|         214.78|          18.26|            0.0|                   0.0|    727.91|            N|      752.58|               22.78|               31.05|               84.9|              32.53|                       33.77|          11.07|          23.91|                 0.0|               40.81|               8.95|               0.02|                     0.0|                  435.94|    73.1|        3.78|            0.06|            NULL|            NULL| Smartphone| Smartphone| Smartphone|     Android|     Android|     Android|        4G|        4G|        4G|    USIM  |    USIM  |    USIM  |DUAL SIM|DUAL SIM|DUAL SIM|
# +--------+--------------+-------+--------------------+--------------------+----------+-------------+--------+-------------+----------------+-------+---------------+--------------------+-------------------+-----------+--------+---------+--------+-----------------+------------------+-----------------+------+------+----------+----------+--------+--------+--------------+--------------+---------------+---------------+----------------+----------------+----------------+---------------+---------------+---------------+----------------------+----------+-------------+------------+--------------------+--------------------+-------------------+-------------------+----------------------------+---------------+---------------+--------------------+--------------------+-------------------+-------------------+------------------------+------------------------+--------+------------+----------------+----------------+----------------+-----------+-----------+-----------+------------+------------+------------+----------+----------+----------+----------+----------+----------+--------+--------+--------+
# only showing top 2 rows

# %%
# SELECTING COLUMNS:

# df.MSISDN #  Works only if column name is a valid Python identifier (e.g. no spaces, special characters).
# df['MSISDN'] # This is more robust and supports any column name (even with spaces or special chars).

from pyspark.sql.functions import col
# df.select(col("MSISDN"), col('MSISDN'))# col(): Preferred when chaining expressions like transformations, filters, or with withColumn().
# df.select('MSISDN', 'MSISDN') # to return a DataFrame with one or more columns

'''
# df.columns[0] # using the index to access the first column, from the .columns list; 
# df.select(df.columns[0])
'''

df.select(
    (col('MSISDN') / 1000).alias('PHONE_NUMBER'),
    # col('TE').alias('TE')
    ).show(10)  # Show the first 3 rows of the 'NUMBER' column with an alias
# Out:
# +------------+
# |PHONE_NUMBER|
# +------------+
# |   54924.133|
# |   54846.497|
# |   57369.115|
# |   57113.437|
# |   58468.805|
# |   57228.141|
# |   57119.226|
# |   57118.074|
# |   54881.304|
# |   57320.678|
# +------------+
# only showing top 10 rows

# %%
print(df.dtypes, "\n") # Get the data types of each column in the DataFrame as a list of tuples [(column_name, data_type), ...]
print(df.schema, "\n")  # Get the schema of the DataFrame, which includes column names and data types
df.printSchema()  # Print the schema of the DataFrame in a tree format
# Out:
# [('MSISDN', 'int'), ('NID', 'string'), ('NID_LEN', 'int'), ('CUSTOMERIDNAME', 'string'), ('EMAIL', 'string'), ('GROSS_DATE', 'string'), ('CUSTOMER_TYPE', 'string'), ('USERTYPE', 'string'), ('SUBSCRIBERCAT', 'string'), ('SUBSCRIBERSUBCAT', 'string'), ('SEGMENT', 'string'), ('POSTPAID_TARIFF', 'string'), ('POSTPAID_MAINPRODUCT', 'string'), ('POSTPAID_SUBPRODUCT', 'string'), ('NATIONALITY', 'string'), ('AON_DAYS', 'int'), ('AON_MONTH', 'double'), ('AON_YEAR', 'double'), ('ALTERNATE_MOB_NUM', 'string'), ('FAVOURITE_LOCATION', 'string'), ('DAYS_INACT  BAL_1', 'int'), ('BAL_2', 'double'), ('BAL_3', 'double'), ('DATA_USERS', 'double'), ('PACK_USERS', 'string'), ('PACK_90D', 'string'), ('PACK_30D', 'int'), ('DAILY_PACK_90D', 'int'), ('DAILY_PACK_30D', 'int'), ('WEEKLY_PACK_90D', 'int'), ('WEEKLY_PACK_30D', 'int'), ('MONTHLY_PACK_90D', 'int'), ('MONTHLY_PACK_30D', 'int'), ('RECHARGE_VAL_30D', 'int'), ('RECHARGE_VAL_D1', 'double'), ('RECHARGE_VAL_D2', 'double'), ('RECHARGE_VAL_D3', 'double'), ('AIRTIME_USG YOUTH_PACK', 'double'), ('TOTAL_ARPU', 'double'), ('ONNET_REVENUE', 'string'), ('XNET_REVENUE', 'double'), ('ONNET_TOTAL_MINS_90D', 'double'), ('ONNET_TOTAL_MINS_30D', 'double'), ('XNET_TOTAL_MINS_90D', 'double'), ('XNET_TOTAL_MINS_30D', 'double'), ('VOICE_INCOMING_ARPU SMS_ARPU', 'double'), ('DATA_USG_GB_90D', 'double'), ('DATA_USG_GB_30D', 'double'), ('DATA_PAYG_USG_GB_90D', 'double'), ('DATA_PAYG_USG_GB_30D', 'double'), ('TOTAL_DATA_ARPU_90D', 'double'), ('TOTAL_DATA_ARPU_30D', 'double'), ('TOTAL_DATA_PAYG_ARPU_90D', 'double'), ('TOTAL_DATA_PAYG_ARPU_30D', 'double'), ('ILD_ARPU', 'double'), ('ILD_SMS_ARPU', 'double'), ('DEVICE_SUBTYPE_1', 'double'), ('DEVICE_SUBTYPE_2', 'double'), ('DEVICE_SUBTYPE_3', 'double'), ('OS_SYSTEM_1', 'string'), ('OS_SYSTEM_2', 'string'), ('OS_SYSTEM_3', 'string'), ('TECHNOLOGY_1', 'string'), ('TECHNOLOGY_2', 'string'), ('TECHNOLOGY_3', 'string'), ('SIM_TYPE_1', 'string'), ('SIM_TYPE_2', 'string'), ('SIM_TYPE_3', 'string'), ('DUAL_SIM_1', 'string'), ('DUAL_SIM_2', 'string'), ('DUAL_SIM_3', 'string'), ('ESIM_1', 'string'), ('ESIM_2', 'string'), ('ESIM_3', 'string')]
#
# StructType([StructField('MSISDN', IntegerType(), True), StructField('NID', StringType(), True), StructField('NID_LEN', IntegerType(), True), StructField('CUSTOMERIDNAME', StringType(), True), StructField('EMAIL', StringType(), True), StructField('GROSS_DATE', StringType(), True), StructField('CUSTOMER_TYPE', StringType(), True), StructField('USERTYPE', StringType(), True), StructField('SUBSCRIBERCAT', StringType(), True), StructField('SUBSCRIBERSUBCAT', StringType(), True), StructField('SEGMENT', StringType(), True), StructField('POSTPAID_TARIFF', StringType(), True), StructField('POSTPAID_MAINPRODUCT', StringType(), True), StructField('POSTPAID_SUBPRODUCT', StringType(), True), StructField('NATIONALITY', StringType(), True), StructField('AON_DAYS', IntegerType(), True), StructField('AON_MONTH', DoubleType(), True), StructField('AON_YEAR', DoubleType(), True), StructField('ALTERNATE_MOB_NUM', StringType(), True), StructField('FAVOURITE_LOCATION', StringType(), True), StructField('DAYS_INACT  BAL_1', IntegerType(), True), StructField('BAL_2', DoubleType(), True), StructField('BAL_3', DoubleType(), True), StructField('DATA_USERS', DoubleType(), True), StructField('PACK_USERS', StringType(), True), StructField('PACK_90D', StringType(), True), StructField('PACK_30D', IntegerType(), True), StructField('DAILY_PACK_90D', IntegerType(), True), StructField('DAILY_PACK_30D', IntegerType(), True), StructField('WEEKLY_PACK_90D', IntegerType(), True), StructField('WEEKLY_PACK_30D', IntegerType(), True), StructField('MONTHLY_PACK_90D', IntegerType(), True), StructField('MONTHLY_PACK_30D', IntegerType(), True), StructField('RECHARGE_VAL_30D', IntegerType(), True), StructField('RECHARGE_VAL_D1', DoubleType(), True), StructField('RECHARGE_VAL_D2', DoubleType(), True), StructField('RECHARGE_VAL_D3', DoubleType(), True), StructField('AIRTIME_USG YOUTH_PACK', DoubleType(), True), StructField('TOTAL_ARPU', DoubleType(), True), StructField('ONNET_REVENUE', StringType(), True), StructField('XNET_REVENUE', DoubleType(), True), StructField('ONNET_TOTAL_MINS_90D', DoubleType(), True), StructField('ONNET_TOTAL_MINS_30D', DoubleType(), True), StructField('XNET_TOTAL_MINS_90D', DoubleType(), True), StructField('XNET_TOTAL_MINS_30D', DoubleType(), True), StructField('VOICE_INCOMING_ARPU SMS_ARPU', DoubleType(), True), StructField('DATA_USG_GB_90D', DoubleType(), True), StructField('DATA_USG_GB_30D', DoubleType(), True), StructField('DATA_PAYG_USG_GB_90D', DoubleType(), True), StructField('DATA_PAYG_USG_GB_30D', DoubleType(), True), StructField('TOTAL_DATA_ARPU_90D', DoubleType(), True), StructField('TOTAL_DATA_ARPU_30D', DoubleType(), True), StructField('TOTAL_DATA_PAYG_ARPU_90D', DoubleType(), True), StructField('TOTAL_DATA_PAYG_ARPU_30D', DoubleType(), True), StructField('ILD_ARPU', DoubleType(), True), StructField('ILD_SMS_ARPU', DoubleType(), True), StructField('DEVICE_SUBTYPE_1', DoubleType(), True), StructField('DEVICE_SUBTYPE_2', DoubleType(), True), StructField('DEVICE_SUBTYPE_3', DoubleType(), True), StructField('OS_SYSTEM_1', StringType(), True), StructField('OS_SYSTEM_2', StringType(), True), StructField('OS_SYSTEM_3', StringType(), True), StructField('TECHNOLOGY_1', StringType(), True), StructField('TECHNOLOGY_2', StringType(), True), StructField('TECHNOLOGY_3', StringType(), True), StructField('SIM_TYPE_1', StringType(), True), StructField('SIM_TYPE_2', StringType(), True), StructField('SIM_TYPE_3', StringType(), True), StructField('DUAL_SIM_1', StringType(), True), StructField('DUAL_SIM_2', StringType(), True), StructField('DUAL_SIM_3', StringType(), True), StructField('ESIM_1', StringType(), True), StructField('ESIM_2', StringType(), True), StructField('ESIM_3', StringType(), True)])
#
# root
#  |-- MSISDN: integer (nullable = true)
#  |-- NID: string (nullable = true)
#  |-- NID_LEN: integer (nullable = true)
#  |-- CUSTOMERIDNAME: string (nullable = true)
#  |-- EMAIL: string (nullable = true)
#  |-- GROSS_DATE: string (nullable = true)
#  |-- CUSTOMER_TYPE: string (nullable = true)
#  |-- USERTYPE: string (nullable = true)
#  |-- SUBSCRIBERCAT: string (nullable = true)
#  |-- SUBSCRIBERSUBCAT: string (nullable = true)
#  |-- SEGMENT: string (nullable = true)
#  |-- POSTPAID_TARIFF: string (nullable = true)
#  |-- POSTPAID_MAINPRODUCT: string (nullable = true)
#  |-- POSTPAID_SUBPRODUCT: string (nullable = true)
#  |-- NATIONALITY: string (nullable = true)
#  |-- AON_DAYS: integer (nullable = true)
#  |-- AON_MONTH: double (nullable = true)
#  |-- AON_YEAR: double (nullable = true)
#  |-- ALTERNATE_MOB_NUM: string (nullable = true)
#  |-- FAVOURITE_LOCATION: string (nullable = true)
#  |-- DAYS_INACT  BAL_1: integer (nullable = true)
#  |-- BAL_2: double (nullable = true)
#  |-- BAL_3: double (nullable = true)
#  |-- DATA_USERS: double (nullable = true)
#  |-- PACK_USERS: string (nullable = true)
#  |-- PACK_90D: string (nullable = true)
#  |-- PACK_30D: integer (nullable = true)
#  |-- DAILY_PACK_90D: integer (nullable = true)
#  |-- DAILY_PACK_30D: integer (nullable = true)
#  |-- WEEKLY_PACK_90D: integer (nullable = true)
#  |-- WEEKLY_PACK_30D: integer (nullable = true)
#  |-- MONTHLY_PACK_90D: integer (nullable = true)
#  |-- MONTHLY_PACK_30D: integer (nullable = true)
#  |-- RECHARGE_VAL_30D: integer (nullable = true)
#  |-- RECHARGE_VAL_D1: double (nullable = true)
#  |-- RECHARGE_VAL_D2: double (nullable = true)
#  |-- RECHARGE_VAL_D3: double (nullable = true)
#  |-- AIRTIME_USG YOUTH_PACK: double (nullable = true)
#  |-- TOTAL_ARPU: double (nullable = true)
#  |-- ONNET_REVENUE: string (nullable = true)
#  |-- XNET_REVENUE: double (nullable = true)
#  |-- ONNET_TOTAL_MINS_90D: double (nullable = true)
#  |-- ONNET_TOTAL_MINS_30D: double (nullable = true)
#  |-- XNET_TOTAL_MINS_90D: double (nullable = true)
#  |-- XNET_TOTAL_MINS_30D: double (nullable = true)
#  |-- VOICE_INCOMING_ARPU SMS_ARPU: double (nullable = true)
#  |-- DATA_USG_GB_90D: double (nullable = true)
#  |-- DATA_USG_GB_30D: double (nullable = true)
#  |-- DATA_PAYG_USG_GB_90D: double (nullable = true)
#  |-- DATA_PAYG_USG_GB_30D: double (nullable = true)
#  |-- TOTAL_DATA_ARPU_90D: double (nullable = true)
#  |-- TOTAL_DATA_ARPU_30D: double (nullable = true)
#  |-- TOTAL_DATA_PAYG_ARPU_90D: double (nullable = true)
#  |-- TOTAL_DATA_PAYG_ARPU_30D: double (nullable = true)
#  |-- ILD_ARPU: double (nullable = true)
#  |-- ILD_SMS_ARPU: double (nullable = true)
#  |-- DEVICE_SUBTYPE_1: double (nullable = true)
#  |-- DEVICE_SUBTYPE_2: double (nullable = true)
#  |-- DEVICE_SUBTYPE_3: double (nullable = true)
#  |-- OS_SYSTEM_1: string (nullable = true)
#  |-- OS_SYSTEM_2: string (nullable = true)
#  |-- OS_SYSTEM_3: string (nullable = true)
#  |-- TECHNOLOGY_1: string (nullable = true)
#  |-- TECHNOLOGY_2: string (nullable = true)
#  |-- TECHNOLOGY_3: string (nullable = true)
#  |-- SIM_TYPE_1: string (nullable = true)
#  |-- SIM_TYPE_2: string (nullable = true)
#  |-- SIM_TYPE_3: string (nullable = true)
#  |-- DUAL_SIM_1: string (nullable = true)
#  |-- DUAL_SIM_2: string (nullable = true)
#  |-- DUAL_SIM_3: string (nullable = true)
#  |-- ESIM_1: string (nullable = true)
#  |-- ESIM_2: string (nullable = true)
#  |-- ESIM_3: string (nullable = true)

# %%
# Adding a new column to the DataFrame
from pyspark.sql.functions import lit, concat
d = df.withColumn(colName='Phone', col=concat(lit('230'), col("MSISDN").cast('string'))) # Add a new column 'Generated' by concatenating '230' with the 'NUMBER' column

d.schema  # Show the DataFrame with the new column
d.show(2)
# Out:
# +--------+--------------+-------+--------------------+--------------------+----------+-------------+--------+-------------+----------------+-------+---------------+--------------------+-------------------+-----------+--------+---------+--------+-----------------+------------------+-----------------+------+------+----------+----------+--------+--------+--------------+--------------+---------------+---------------+----------------+----------------+----------------+---------------+---------------+---------------+----------------------+----------+-------------+------------+--------------------+--------------------+-------------------+-------------------+----------------------------+---------------+---------------+--------------------+--------------------+-------------------+-------------------+------------------------+------------------------+--------+------------+----------------+----------------+----------------+-----------+-----------+-----------+------------+------------+------------+----------+----------+----------+----------+----------+----------+--------+--------+--------+-----------+
# |  MSISDN|           NID|NID_LEN|      CUSTOMERIDNAME|               EMAIL|GROSS_DATE|CUSTOMER_TYPE|USERTYPE|SUBSCRIBERCAT|SUBSCRIBERSUBCAT|SEGMENT|POSTPAID_TARIFF|POSTPAID_MAINPRODUCT|POSTPAID_SUBPRODUCT|NATIONALITY|AON_DAYS|AON_MONTH|AON_YEAR|ALTERNATE_MOB_NUM|FAVOURITE_LOCATION|DAYS_INACT  BAL_1| BAL_2| BAL_3|DATA_USERS|PACK_USERS|PACK_90D|PACK_30D|DAILY_PACK_90D|DAILY_PACK_30D|WEEKLY_PACK_90D|WEEKLY_PACK_30D|MONTHLY_PACK_90D|MONTHLY_PACK_30D|RECHARGE_VAL_30D|RECHARGE_VAL_D1|RECHARGE_VAL_D2|RECHARGE_VAL_D3|AIRTIME_USG YOUTH_PACK|TOTAL_ARPU|ONNET_REVENUE|XNET_REVENUE|ONNET_TOTAL_MINS_90D|ONNET_TOTAL_MINS_30D|XNET_TOTAL_MINS_90D|XNET_TOTAL_MINS_30D|VOICE_INCOMING_ARPU SMS_ARPU|DATA_USG_GB_90D|DATA_USG_GB_30D|DATA_PAYG_USG_GB_90D|DATA_PAYG_USG_GB_30D|TOTAL_DATA_ARPU_90D|TOTAL_DATA_ARPU_30D|TOTAL_DATA_PAYG_ARPU_90D|TOTAL_DATA_PAYG_ARPU_30D|ILD_ARPU|ILD_SMS_ARPU|DEVICE_SUBTYPE_1|DEVICE_SUBTYPE_2|DEVICE_SUBTYPE_3|OS_SYSTEM_1|OS_SYSTEM_2|OS_SYSTEM_3|TECHNOLOGY_1|TECHNOLOGY_2|TECHNOLOGY_3|SIM_TYPE_1|SIM_TYPE_2|SIM_TYPE_3|DUAL_SIM_1|DUAL_SIM_2|DUAL_SIM_3|  ESIM_1|  ESIM_2|  ESIM_3|      Phone|
# +--------+--------------+-------+--------------------+--------------------+----------+-------------+--------+-------------+----------------+-------+---------------+--------------------+-------------------+-----------+--------+---------+--------+-----------------+------------------+-----------------+------+------+----------+----------+--------+--------+--------------+--------------+---------------+---------------+----------------+----------------+----------------+---------------+---------------+---------------+----------------------+----------+-------------+------------+--------------------+--------------------+-------------------+-------------------+----------------------------+---------------+---------------+--------------------+--------------------+-------------------+-------------------+------------------------+------------------------+--------+------------+----------------+----------------+----------------+-----------+-----------+-----------+------------+------------+------------+----------+----------+----------+----------+----------+----------+--------+--------+--------+-----------+
# |54924133|J0711874907942|     14|        WENSLEY JEAN|JEANPOMPIER0517@G...| 21-Jul-15|       MOBILE| PREPAID|   INDIVIDUAL|            GOLD|  IVORY|           NULL|                NULL|               NULL|       HOME|    3222|   105.84|    8.83|             NULL|        BELLE ROSE|                0|1.8619|1.8621|    1.8621|         Y|       Y|       3|             2|             3|              2|           NULL|            NULL|            NULL|            NULL|            0.0|            0.0|            0.0|                   0.0|     78.67|            N|       80.99|               17.56|                4.69|              14.63|                2.8|                        1.32|           NULL|           2.32|                 0.0|                0.99|               0.99|               0.01|                     0.0|                   18.26|    NULL|        1.64|             0.3|            NULL|            NULL| Smartphone| Smartphone| Smartphone|     Android|     Android|     Android|        5G|        5G|        5G|    USIM  |    USIM  |    USIM  |DUAL SIM|DUAL SIM|DUAL SIM|23054924133|
# |54846497|B160985220041C|     14|MARIE ANGELO BOOD...|                NULL| 10-Apr-24|       MOBILE| PREPAID|   INDIVIDUAL|            GOLD| SILVER|           NULL|                NULL|               NULL|       HOME|     417|    13.68|    1.14|             NULL|         ST HUBERT|                0|8.7E-4|   0.0|       0.0|         Y|       Y|      19|            11|            19|             11|           NULL|            NULL|               1|            NULL|         214.78|          18.26|            0.0|                   0.0|    727.91|            N|      752.58|               22.78|               31.05|               84.9|              32.53|                       33.77|          11.07|          23.91|                 0.0|               40.81|               8.95|               0.02|                     0.0|                  435.94|    73.1|        3.78|            0.06|            NULL|            NULL| Smartphone| Smartphone| Smartphone|     Android|     Android|     Android|        4G|        4G|        4G|    USIM  |    USIM  |    USIM  |DUAL SIM|DUAL SIM|DUAL SIM|23054846497|
# +--------+--------------+-------+--------------------+--------------------+----------+-------------+--------+-------------+----------------+-------+---------------+--------------------+-------------------+-----------+--------+---------+--------+-----------------+------------------+-----------------+------+------+----------+----------+--------+--------+--------------+--------------+---------------+---------------+----------------+----------------+----------------+---------------+---------------+---------------+----------------------+----------+-------------+------------+--------------------+--------------------+-------------------+-------------------+----------------------------+---------------+---------------+--------------------+--------------------+-------------------+-------------------+------------------------+------------------------+--------+------------+----------------+----------------+----------------+-----------+-----------+-----------+------------+------------+------------+----------+----------+----------+----------+----------+----------+--------+--------+--------+-----------+
# only showing top 2 rows

# %%
# Dropping a column from the DataFrame

dropped_df = d.drop('Phone')  # Drop duplicates based on the 'Generated Column'
dropped_df.show(2)  # Show the first 5 rows of the DataFrame after dropping duplicates

# Renaming a column in the DataFrame

renamed_df = dropped_df.withColumnRenamed(existing='MSISDN', new='PHONE_NUMBER')  # Rename the 'NUMBER' column to 'PHONE_NUMBER'
renamed_df.show(2)  # Show the first 5 rows of the DataFrame after renaming the column
# Out:
# +--------+--------------+-------+--------------------+--------------------+----------+-------------+--------+-------------+----------------+-------+---------------+--------------------+-------------------+-----------+--------+---------+--------+-----------------+------------------+-----------------+------+------+----------+----------+--------+--------+--------------+--------------+---------------+---------------+----------------+----------------+----------------+---------------+---------------+---------------+----------------------+----------+-------------+------------+--------------------+--------------------+-------------------+-------------------+----------------------------+---------------+---------------+--------------------+--------------------+-------------------+-------------------+------------------------+------------------------+--------+------------+----------------+----------------+----------------+-----------+-----------+-----------+------------+------------+------------+----------+----------+----------+----------+----------+----------+--------+--------+--------+
# |  MSISDN|           NID|NID_LEN|      CUSTOMERIDNAME|               EMAIL|GROSS_DATE|CUSTOMER_TYPE|USERTYPE|SUBSCRIBERCAT|SUBSCRIBERSUBCAT|SEGMENT|POSTPAID_TARIFF|POSTPAID_MAINPRODUCT|POSTPAID_SUBPRODUCT|NATIONALITY|AON_DAYS|AON_MONTH|AON_YEAR|ALTERNATE_MOB_NUM|FAVOURITE_LOCATION|DAYS_INACT  BAL_1| BAL_2| BAL_3|DATA_USERS|PACK_USERS|PACK_90D|PACK_30D|DAILY_PACK_90D|DAILY_PACK_30D|WEEKLY_PACK_90D|WEEKLY_PACK_30D|MONTHLY_PACK_90D|MONTHLY_PACK_30D|RECHARGE_VAL_30D|RECHARGE_VAL_D1|RECHARGE_VAL_D2|RECHARGE_VAL_D3|AIRTIME_USG YOUTH_PACK|TOTAL_ARPU|ONNET_REVENUE|XNET_REVENUE|ONNET_TOTAL_MINS_90D|ONNET_TOTAL_MINS_30D|XNET_TOTAL_MINS_90D|XNET_TOTAL_MINS_30D|VOICE_INCOMING_ARPU SMS_ARPU|DATA_USG_GB_90D|DATA_USG_GB_30D|DATA_PAYG_USG_GB_90D|DATA_PAYG_USG_GB_30D|TOTAL_DATA_ARPU_90D|TOTAL_DATA_ARPU_30D|TOTAL_DATA_PAYG_ARPU_90D|TOTAL_DATA_PAYG_ARPU_30D|ILD_ARPU|ILD_SMS_ARPU|DEVICE_SUBTYPE_1|DEVICE_SUBTYPE_2|DEVICE_SUBTYPE_3|OS_SYSTEM_1|OS_SYSTEM_2|OS_SYSTEM_3|TECHNOLOGY_1|TECHNOLOGY_2|TECHNOLOGY_3|SIM_TYPE_1|SIM_TYPE_2|SIM_TYPE_3|DUAL_SIM_1|DUAL_SIM_2|DUAL_SIM_3|  ESIM_1|  ESIM_2|  ESIM_3|
# +--------+--------------+-------+--------------------+--------------------+----------+-------------+--------+-------------+----------------+-------+---------------+--------------------+-------------------+-----------+--------+---------+--------+-----------------+------------------+-----------------+------+------+----------+----------+--------+--------+--------------+--------------+---------------+---------------+----------------+----------------+----------------+---------------+---------------+---------------+----------------------+----------+-------------+------------+--------------------+--------------------+-------------------+-------------------+----------------------------+---------------+---------------+--------------------+--------------------+-------------------+-------------------+------------------------+------------------------+--------+------------+----------------+----------------+----------------+-----------+-----------+-----------+------------+------------+------------+----------+----------+----------+----------+----------+----------+--------+--------+--------+
# |54924133|J0711874907942|     14|        WENSLEY JEAN|JEANPOMPIER0517@G...| 21-Jul-15|       MOBILE| PREPAID|   INDIVIDUAL|            GOLD|  IVORY|           NULL|                NULL|               NULL|       HOME|    3222|   105.84|    8.83|             NULL|        BELLE ROSE|                0|1.8619|1.8621|    1.8621|         Y|       Y|       3|             2|             3|              2|           NULL|            NULL|            NULL|            NULL|            0.0|            0.0|            0.0|                   0.0|     78.67|            N|       80.99|               17.56|                4.69|              14.63|                2.8|                        1.32|           NULL|           2.32|                 0.0|                0.99|               0.99|               0.01|                     0.0|                   18.26|    NULL|        1.64|             0.3|            NULL|            NULL| Smartphone| Smartphone| Smartphone|     Android|     Android|     Android|        5G|        5G|        5G|    USIM  |    USIM  |    USIM  |DUAL SIM|DUAL SIM|DUAL SIM|
# |54846497|B160985220041C|     14|MARIE ANGELO BOOD...|                NULL| 10-Apr-24|       MOBILE| PREPAID|   INDIVIDUAL|            GOLD| SILVER|           NULL|                NULL|               NULL|       HOME|     417|    13.68|    1.14|             NULL|         ST HUBERT|                0|8.7E-4|   0.0|       0.0|         Y|       Y|      19|            11|            19|             11|           NULL|            NULL|               1|            NULL|         214.78|          18.26|            0.0|                   0.0|    727.91|            N|      752.58|               22.78|               31.05|               84.9|              32.53|                       33.77|          11.07|          23.91|                 0.0|               40.81|               8.95|               0.02|                     0.0|                  435.94|    73.1|        3.78|            0.06|            NULL|            NULL| Smartphone| Smartphone| Smartphone|     Android|     Android|     Android|        4G|        4G|        4G|    USIM  |    USIM  |    USIM  |DUAL SIM|DUAL SIM|DUAL SIM|
# +--------+--------------+-------+--------------------+--------------------+----------+-------------+--------+-------------+----------------+-------+---------------+--------------------+-------------------+-----------+--------+---------+--------+-----------------+------------------+-----------------+------+------+----------+----------+--------+--------+--------------+--------------+---------------+---------------+----------------+----------------+----------------+---------------+---------------+---------------+----------------------+----------+-------------+------------+--------------------+--------------------+-------------------+-------------------+----------------------------+---------------+---------------+--------------------+--------------------+-------------------+-------------------+------------------------+------------------------+--------+------------+----------------+----------------+----------------+-----------+-----------+-----------+------------+------------+------------+----------+----------+----------+----------+----------+----------+--------+--------+--------+
# only showing top 2 rows
#
# +------------+--------------+-------+--------------------+--------------------+----------+-------------+--------+-------------+----------------+-------+---------------+--------------------+-------------------+-----------+--------+---------+--------+-----------------+------------------+-----------------+------+------+----------+----------+--------+--------+--------------+--------------+---------------+---------------+----------------+----------------+----------------+---------------+---------------+---------------+----------------------+----------+-------------+------------+--------------------+--------------------+-------------------+-------------------+----------------------------+---------------+---------------+--------------------+--------------------+-------------------+-------------------+------------------------+------------------------+--------+------------+----------------+----------------+----------------+-----------+-----------+-----------+------------+------------+------------+----------+----------+----------+----------+----------+----------+--------+--------+--------+
# |PHONE_NUMBER|           NID|NID_LEN|      CUSTOMERIDNAME|               EMAIL|GROSS_DATE|CUSTOMER_TYPE|USERTYPE|SUBSCRIBERCAT|SUBSCRIBERSUBCAT|SEGMENT|POSTPAID_TARIFF|POSTPAID_MAINPRODUCT|POSTPAID_SUBPRODUCT|NATIONALITY|AON_DAYS|AON_MONTH|AON_YEAR|ALTERNATE_MOB_NUM|FAVOURITE_LOCATION|DAYS_INACT  BAL_1| BAL_2| BAL_3|DATA_USERS|PACK_USERS|PACK_90D|PACK_30D|DAILY_PACK_90D|DAILY_PACK_30D|WEEKLY_PACK_90D|WEEKLY_PACK_30D|MONTHLY_PACK_90D|MONTHLY_PACK_30D|RECHARGE_VAL_30D|RECHARGE_VAL_D1|RECHARGE_VAL_D2|RECHARGE_VAL_D3|AIRTIME_USG YOUTH_PACK|TOTAL_ARPU|ONNET_REVENUE|XNET_REVENUE|ONNET_TOTAL_MINS_90D|ONNET_TOTAL_MINS_30D|XNET_TOTAL_MINS_90D|XNET_TOTAL_MINS_30D|VOICE_INCOMING_ARPU SMS_ARPU|DATA_USG_GB_90D|DATA_USG_GB_30D|DATA_PAYG_USG_GB_90D|DATA_PAYG_USG_GB_30D|TOTAL_DATA_ARPU_90D|TOTAL_DATA_ARPU_30D|TOTAL_DATA_PAYG_ARPU_90D|TOTAL_DATA_PAYG_ARPU_30D|ILD_ARPU|ILD_SMS_ARPU|DEVICE_SUBTYPE_1|DEVICE_SUBTYPE_2|DEVICE_SUBTYPE_3|OS_SYSTEM_1|OS_SYSTEM_2|OS_SYSTEM_3|TECHNOLOGY_1|TECHNOLOGY_2|TECHNOLOGY_3|SIM_TYPE_1|SIM_TYPE_2|SIM_TYPE_3|DUAL_SIM_1|DUAL_SIM_2|DUAL_SIM_3|  ESIM_1|  ESIM_2|  ESIM_3|
# +------------+--------------+-------+--------------------+--------------------+----------+-------------+--------+-------------+----------------+-------+---------------+--------------------+-------------------+-----------+--------+---------+--------+-----------------+------------------+-----------------+------+------+----------+----------+--------+--------+--------------+--------------+---------------+---------------+----------------+----------------+----------------+---------------+---------------+---------------+----------------------+----------+-------------+------------+--------------------+--------------------+-------------------+-------------------+----------------------------+---------------+---------------+--------------------+--------------------+-------------------+-------------------+------------------------+------------------------+--------+------------+----------------+----------------+----------------+-----------+-----------+-----------+------------+------------+------------+----------+----------+----------+----------+----------+----------+--------+--------+--------+
# |    54924133|J0711874907942|     14|        WENSLEY JEAN|JEANPOMPIER0517@G...| 21-Jul-15|       MOBILE| PREPAID|   INDIVIDUAL|            GOLD|  IVORY|           NULL|                NULL|               NULL|       HOME|    3222|   105.84|    8.83|             NULL|        BELLE ROSE|                0|1.8619|1.8621|    1.8621|         Y|       Y|       3|             2|             3|              2|           NULL|            NULL|            NULL|            NULL|            0.0|            0.0|            0.0|                   0.0|     78.67|            N|       80.99|               17.56|                4.69|              14.63|                2.8|                        1.32|           NULL|           2.32|                 0.0|                0.99|               0.99|               0.01|                     0.0|                   18.26|    NULL|        1.64|             0.3|            NULL|            NULL| Smartphone| Smartphone| Smartphone|     Android|     Android|     Android|        5G|        5G|        5G|    USIM  |    USIM  |    USIM  |DUAL SIM|DUAL SIM|DUAL SIM|
# |    54846497|B160985220041C|     14|MARIE ANGELO BOOD...|                NULL| 10-Apr-24|       MOBILE| PREPAID|   INDIVIDUAL|            GOLD| SILVER|           NULL|                NULL|               NULL|       HOME|     417|    13.68|    1.14|             NULL|         ST HUBERT|                0|8.7E-4|   0.0|       0.0|         Y|       Y|      19|            11|            19|             11|           NULL|            NULL|               1|            NULL|         214.78|          18.26|            0.0|                   0.0|    727.91|            N|      752.58|               22.78|               31.05|               84.9|              32.53|                       33.77|          11.07|          23.91|                 0.0|               40.81|               8.95|               0.02|                     0.0|                  435.94|    73.1|        3.78|            0.06|            NULL|            NULL| Smartphone| Smartphone| Smartphone|     Android|     Android|     Android|        4G|        4G|        4G|    USIM  |    USIM  |    USIM  |DUAL SIM|DUAL SIM|DUAL SIM|
# +------------+--------------+-------+--------------------+--------------------+----------+-------------+--------+-------------+----------------+-------+---------------+--------------------+-------------------+-----------+--------+---------+--------+-----------------+------------------+-----------------+------+------+----------+----------+--------+--------+--------------+--------------+---------------+---------------+----------------+----------------+----------------+---------------+---------------+---------------+----------------------+----------+-------------+------------+--------------------+--------------------+-------------------+-------------------+----------------------------+---------------+---------------+--------------------+--------------------+-------------------+-------------------+------------------------+------------------------+--------+------------+----------------+----------------+----------------+-----------+-----------+-----------+------------+------------+------------+----------+----------+----------+----------+----------+----------+--------+--------+--------+
# only showing top 2 rows
